# %%
import random
import numpy as np
from plotter import Plotter
import matplotlib.pyplot as plt
import time
import pylab as pl
from IPython import display
import pandas as pd

# %%
x_values = [1,3]
y_values = [2,3]
plt.plot(x_values, y_values, 'bo', linestyle="--")

# %%
def f(x):
    return 2.5*x+5
def isPointAboveOrBelow(x,y):
    if y - 2.5*x-5 > 0:
        return 1
    else:
        return 0

# %%
#train
l = 0.1
class Perceptron:
    no = 2
    bias = 1
    weights = []
    def __init__(self, no, bias):
        self.no = no
        self.bias = bias
        self.weights = [random.randint(1,100) for i in range(no)]
    #activation function
    def activate(self, input):
        sum = 0
        for i in range(len(input)):
            sum += input[i]*self.weights[i]
        if sum > 0:
            return 1 
        else:
            return 0    
            
    def train(self, input, desired):
        guess = self.activate(input)
        error = desired - guess
        if error!=0:
            for i in range(len(input)):
                self.weights[i] += input[i]*l*error            

class NeuralNetwork:
    perceptrons = []
    def __init__(self, no_of_perceptrons):
        for i in range(no_of_perceptrons):
            perceptrons.append(Perceptron(2,1))
    def train():
        input = []
        desired = []
        for i in range(1000):
            x = random.randint(1,100)
            y = random.randint(1,100)
            input.append([x, y])
            desired.append(isPointAboveOrBelow(x,y))
        for i in range(1000):
            for j in range(len(perceptrons)):
                for k in range(len(input)):
                    p1.train(input[k], desired[k])

# %%
p1 = Perceptron(2,1) 

input1 = []
desired1 = []

for i in range(1000):
    x = random.randint(1,100)
    y = random.randint(1,100)
    input1.append([x, y])
    desired1.append(isPointAboveOrBelow(x,y))

for k in range(1000):
    for i in range(len(input)):
        p1.train(input1[i], desired1[i])            

print(p1.weights)
# Out:
# [-343.6999999999985, 126.79999999998414]

# %%
p2 = Perceptron(2,1) 

input2 = []
desired2 = []

for i in range(1000):
    x = random.randint(1,100)
    y = random.randint(1,100)
    input2.append([x, y])
    desired2.append(isPointAboveOrBelow(x,y))

for k in range(1000):
    for i in range(len(input2)):
        p2.train(input2[i], desired2[i])    

print(p2.weights)
# Out:
# [-147.000000000006, 58.399999999999906]

# %%
plt.plot([0,100],[5,255] , 'bo', linestyle="--")
for i in range(100):
    x = random.randint(1,50)
    y = random.randint(1,120)
    flag = p1.activate([x,y])
    clr = 'red'
    if flag == 0:
        clr = 'black'
    plt.scatter(x,y, color=clr)
    display.display(plt.gcf())
    display.clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/python3/lib/python3.9/site-packages/PIL/ImageFile.py:515, in _save(im, fp, tile, bufsize)
#     514 try:
# --> 515     fh = fp.fileno()
#     516     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[146], line 10
#       8     clr = 'black'
#       9 plt.scatter(x,y, color=clr)
# ---> 10 display.display(plt.gcf())
#      11 display.clear_output(wait=True)
#
# File ~/python3/lib/python3.9/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# ...

# %%
correct_guesses = 0
total_guesses = 100
for i in range(total_guesses):
    x = random.randint(1,100)
    y = random.randint(1,100)
    guess = p1.activate([x,y])
    desired = isPointAboveOrBelow(x,y)
    if guess == desired:
        correct_guesses += 1
print("accuracy of p1 : " , correct_guesses/total_guesses)
# Out:
# accuracy :  0.97
